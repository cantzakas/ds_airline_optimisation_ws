# %% [markdown]
# # Prepare and Load Data

# %% [markdown]
# ## Load ipython-sql and connect to database

# %%
# %load_ext sql

# %%
# %sql postgresql://gpadmin:pivotal@gpdb-sandbox:5432/gpadmin
# Out:
# u'Connected: gpadmin@gpadmin'

# %%
# %sql set search_path=pricing, public;
# %sql SELECT VERSION();
# Out:
#  * postgresql://gpadmin:***@gpdb-sandbox:5432/gpadmin
# Done.
#  * postgresql://gpadmin:***@gpdb-sandbox:5432/gpadmin
# 1 rows affected.
# [(u'PostgreSQL 8.3.23 (Greenplum Database 5.7.0 build commit:f7c6eb5cc61b25a7ff9c5a657d6f903befbae013) on x86_64-pc-linux-gnu, compiled by GCC gcc (GCC) 6.2.0, 64-bit compiled on Mar 30 2018 14:19:06',)]

# %% [markdown]
# ## Create and load tables
# ### pricing.airports

# %%
# %%sql
# DROP TABLE IF EXISTS pricing.airports CASCADE;
#
# CREATE TABLE pricing.airports (
#     City TEXT,
#     FAA VARCHAR(3),
#     IATA VARCHAR(3),
#     ICA VARCHAR(4),
#     Airport TEXT,
#     Airport_Role VARCHAR(3),
#     Enplanements BIGINT,
#     Hub_Assignment VARCHAR(3),
#     is_hub INTEGER)
# DISTRIBUTED BY(FAA);
#
# INSERT INTO pricing.airports
#     (city, faa, iata, ica, airport, airport_role, enplanements, hub_assignment, is_hub)
# VALUES
#     ('Birmingham', 'BHM', 'BHM', 'KBHM', 'Birmingham-Shuttlesworth International Airport', 'P-S', '1443215', 'DFW', '0'),
#     ('Dothan', 'DHN', 'DHN', 'KDHN', 'Dothan Regional Airport', 'P-N', '41453', NULL, '0'),
#     ('Huntsville', 'HSV', 'HSV', 'KHSV', 'Huntsville International Airport ("Carl T. Jones Field")', 'P-S', '606127', 'DFW', '0'),
#     ('Mobile', 'MOB', 'MOB', 'KMOB', 'Mobile Regional Airport', 'P-N', '277232', NULL, '0'),
#     ('Montgomery', 'MGM', 'MGM', 'KMGM', 'Montgomery Regional Airport ("Dannelly Field")', 'P-N', '194540', NULL, '0'),
#     ('Anchorage', 'ANC', 'ANC', 'PANC', 'Ted Stevens Anchorage International Airport', 'P-M', '2599313', 'LAX', '0'),
#     ('Anchorage', 'MRI', 'MRI', 'PAMR', 'Merrill Field', 'P-N', '15206', NULL, '0'),
#     ('Aniak', 'ANI', 'ANI', 'PANI', 'Aniak Airport', 'P-N', '18526', NULL, '0'),
#     ('Barrow', 'BRW', 'BRW', 'PABR', 'Wiley Postâ€“Will Rogers Memorial Airport', 'P-N', '40674', NULL, '0'),
#     ('Bethel', 'BET', 'BET', 'PABE', 'Bethel Airport', 'P-N', '140291', NULL, '0'),
#     ('Cordova', 'CDV', 'CDV', 'PACV', 'Merle K. (Mudhole) Smith Airport', 'P-N', '16640', NULL, '0'),
#     ('Deadhorse / Prudhoe Bay', 'SCC', 'SCC', 'PASC', 'Deadhorse Airport (Prudhoe Bay Airport)', 'P-N', '99719', NULL, '0'),
#     ('Dillingham', 'DLG', 'DLG', 'PADL', 'Dillingham Airport', 'P-N', '32215', NULL, '0'),
#     ('Fairbanks', 'FAI', 'FAI', 'PAFA', 'Fairbanks International Airport', 'P-S', '456947', 'LAX', '0'),
#     ('Gustavus', 'GST', 'GST', 'PAGS', 'Gustavus Airport', 'P-N', '11828', NULL, '0'),
#     ('Homer', 'HOM', 'HOM', 'PAHO', 'Homer Airport', 'P-N', '44288', NULL, '0'),
#     ('Juneau', 'JNU', 'JNU', 'PAJN', 'Juneau International Airport', 'P-S', '378741', 'LAX', '0'),
#     ('Kenai', 'ENA', 'ENA', 'PAEN', 'Kenai Municipal Airport', 'P-N', '96565', NULL, '0'),
#     ('Ketchikan', 'KTN', 'KTN', 'PAKT', 'Ketchikan International Airport', 'P-N', '108837', NULL, '0'),
#     ('King Salmon', 'AKN', 'AKN', 'PAKN', 'King Salmon Airport', 'P-N', '42310', NULL, '0'),
#     ('Kodiak', 'ADQ', 'ADQ', 'PADQ', 'Kodiak Airport', 'P-N', '82057', NULL, '0'),
#     ('Kotzebue', 'OTZ', 'OTZ', 'PAOT', 'Ralph Wien Memorial Airport', 'P-N', '66322', NULL, '0'),
#     ('Manokotak', 'MBA', 'KMO', 'PAMB', 'Manokotak Airport', 'P-N', '13393', NULL, '0'),
#     ('Nome', 'OME', 'OME', 'PAOM', 'Nome Airport', 'P-N', '59984', NULL, '0'),
#     ('Petersburg', 'PSG', 'PSG', 'PAPG', 'Petersburg James A. Johnson Airport', 'P-N', '19901', NULL, '0'),
#     ('Sitka', 'SIT', 'SIT', 'PASI', 'Sitka Rocky Gutierrez Airport', 'P-N', '68197', NULL, '0'),
#     ('Skagway', 'SGY', 'SGY', 'PAGY', 'Skagway Airport', 'P-N', '10727', NULL, '0'),
#     ('Unalakleet', 'UNK', 'UNK', 'PAUN', 'Unalakleet Airport', 'P-N', '12327', NULL, '0'),
#     ('Unalaska', 'DUT', 'DUT', 'PADU', 'Unalaska Airport (Tom Madsen Airport)', 'P-N', '28234', NULL, '0'),
#     ('Valdez', 'VDZ', 'VDZ', 'PAVD', 'Valdez Airport (Pioneer Field)', 'P-N', '14981', NULL, '0'),
#     ('Wrangell', 'WRG', 'WRG', 'PAWG', 'Wrangell Airport', 'P-N', '10601', NULL, '0'),
#     ('Yakutat', 'YAK', 'YAK', 'PAYA', 'Yakutat Airport', 'P-N', '11028', NULL, '0'),
#     ('Bullhead City', 'IFP', 'IFP', 'KIFP', 'Laughlin/Bullhead International Airport', 'P-N', '122192', NULL, '0'),
#     ('Flagstaff', 'FLG', 'FLG', 'KFLG', 'Flagstaff Pulliam Airport', 'P-N', '51765', NULL, '0'),
#     ('Grand Canyon / Tusayan', 'GCN', 'GCN', 'KGCN', 'Grand Canyon National Park Airport', 'P-S', '294436', 'ORD', '0'),
#     ('Page', 'PGA', 'PGA', 'KPGA', 'Page Municipal Airport', 'P-N', '33118', NULL, '0'),
#     ('Peach Springs', '1G4', 'GCW', NULL, 'Grand Canyon West Airport', 'P-N', '65351', NULL, '0'),
#     ('Phoenix', 'PHX', 'PHX', 'KPHX', 'Phoenix Sky Harbor International Airport', 'P-L', '19450576', 'DFW', '0'),
#     ('Tucson', 'TUS', 'TUS', 'KTUS', 'Tucson International Airport', 'P-M', '2070573', 'LAX', '0'),
#     ('Yuma', 'NYL', 'YUM', 'KNYL', 'Yuma International Airport / MCAS Yuma', 'P-N', '87812', NULL, '0'),
#     ('Fayetteville', 'XNA', 'XNA', 'KXNA', 'Northwest Arkansas Regional Airport', 'P-S', '547871', 'ORD', '0'),
#     ('Fort Smith', 'FSM', 'FSM', 'KFSM', 'Fort Smith Regional Airport', 'P-N', '85095', NULL, '0'),
#     ('Little Rock', 'LIT', 'LIT', 'KLIT', 'Little Rock National Airport (Adams Field)', 'P-S', '1181846', 'ORD', '0'),
#     ('Texarkana', 'TXK', 'TXK', 'KTXK', 'Texarkana Regional Airport (Webb Field)', 'P-N', '29820', NULL, '0'),
#     ('Arcata / Eureka', 'ACV', 'ACV', 'KACV', 'Arcata Airport', 'P-N', '106637', NULL, '0'),
#     ('Bakersfield', 'BFL', 'BFL', 'KBFL', 'Meadows Field', 'P-N', '141847', NULL, '0'),
#     ('Burbank', 'BUR', 'BUR', 'KBUR', 'Bob Hope Airport', 'P-M', '2647287', 'LAX', '0'),
#     ('Carlsbad', 'CRQ', 'CLD', 'KCRQ', 'McClellan-Palomar Airport', 'P-N', '35033', NULL, '0'),
#     ('Chico', 'CIC', 'CIC', 'KCIC', 'Chico Municipal Airport', 'P-N', '24809', NULL, '0'),
#     ('Crescent City', 'CEC', 'CEC', 'KCEC', 'Del Norte County Airport (Jack McNamara Field)', 'P-N', '12541', NULL, '0'),
#     ('Fresno', 'FAT', 'FAT', 'KFAT', 'Fresno Yosemite International Airport', 'P-S', '600489', 'LAX', '0'),
#     ('Inyokern', 'IYK', 'IYK', 'KIYK', 'Inyokern Airport', 'P-N', '11149', NULL, '0'),
#     ('Long Beach', 'LGB', 'LGB', 'KLGB', 'Long Beach Airport (Daugherty Field)', 'P-S', '1413251', 'LAX', '0'),
#     ('Los Angeles', 'LAX', 'LAX', 'KLAX', 'Los Angeles International Airport', 'P-L', '28861477', NULL, '1'),
#     ('Modesto', 'MOD', 'MOD', 'KMOD', 'Modesto City-County Airport (Harry Sham Field)', 'P-N', '37082', NULL, '0'),
#     ('Monterey', 'MRY', 'MRY', 'KMRY', 'Monterey Peninsula Airport', 'P-N', '207964', NULL, '0'),
#     ('Oakland', 'OAK', 'OAK', 'KOAK', 'Oakland International Airport', 'P-M', '5583748', 'LAX', '0'),
#     ('Ontario', 'ONT', 'ONT', 'KONT', 'Ontario International Airport', 'P-M', '2998110', 'LAX', '0'),
#     ('Oxnard', 'OXR', 'OXR', 'KOXR', 'Oxnard Airport', 'P-N', '15961', NULL, '0'),
#     ('Palm Springs', 'PSP', 'PSP', 'KPSP', 'Palm Springs International Airport', 'P-S', '772906', 'LAX', '0'),
#     ('Redding', 'RDD', 'RDD', 'KRDD', 'Redding Municipal Airport', 'P-N', '63331', NULL, '0'),
#     ('Sacramento', 'SMF', 'SMF', 'KSMF', 'Sacramento International Airport', 'P-M', '4986771', 'LAX', '0'),
#     ('San Diego', 'SAN', 'SAN', 'KSAN', 'San Diego International Airport', 'P-L', '9007617', 'LAX', '0'),
#     ('San Francisco', 'SFO', 'SFO', 'KSFO', 'San Francisco International Airport', 'P-L', '18135827', 'LAX', '0'),
#     ('San Jose', 'SJC', 'SJC', 'KSJC', 'Norman Y. Mineta San JosÃ© International Airport', 'P-M', '4780264', 'LAX', '0'),
#     ('San Luis Obispo', 'SBP', 'SBP', 'KSBP', 'San Luis Obispo County Regional Airport (McChesney Field)', 'P-N', '150089', NULL, '0'),
#     ('Santa Ana', 'SNA', 'SNA', 'KSNA', 'John Wayne Airport - Orange County (was Orange County Airport)', 'P-M', '4464380', 'LAX', '0'),
#     ('Santa Barbara', 'SBA', 'SBA', 'KSBA', 'Santa Barbara Municipal Airport', 'P-S', '413929', 'LAX', '0'),
#     ('Santa Maria', 'SMX', 'SMX', 'KSMX', 'Santa Maria Public Airport (Capt G. Allan Hancock Field)', 'P-N', '54925', NULL, '0'),
#     ('Santa Rosa', 'STS', 'STS', 'KSTS', 'Charles M. Schulz - Sonoma County Airport', 'P-N', '100676', NULL, '0'),
#     ('Stockton', 'SCK', 'SCK', 'KSCK', 'Stockton Metropolitan Airport', 'P-N', '36935', NULL, '0'),
#     ('Aspen', 'ASE', 'ASE', 'KASE', 'Aspen-Pitkin County Airport (Sardy Field)', 'P-N', '213381', NULL, '0'),
#     ('Colorado Springs', 'COS', 'COS', 'KCOS', 'City of Colorado Springs Municipal Airport', 'P-S', '997348', 'ORD', '0'),
#     ('Denver', 'DEN', 'DEN', 'KDEN', 'Denver International Airport', 'P-L', '24287939', 'DFW', '0'),
#     ('Durango', 'DRO', 'DRO', 'KDRO', 'Durango-La Plata County Airport', 'P-N', '134386', NULL, '0'),
#     ('Eagle', 'EGE', 'EGE', 'KEGE', 'Eagle County Regional Airport', 'P-N', '212832', NULL, '0'),
#     ('Fort Collins / Loveland', 'FNL', 'FNL', 'KFNL', 'Fort Collins-Loveland Municipal Airport', 'P-N', '31094', NULL, '0'),
#     ('Grand Junction', 'GJT', 'GJT', 'KGJT', 'Grand Junction Regional Airport (Walker Field)', 'P-N', '212588', NULL, '0'),
#     ('Gunnison', 'GUC', 'GUC', 'KGUC', 'Gunnison-Crested Butte Regional Airport', 'P-N', '36035', NULL, '0'),
#     ('Hayden', 'HDN', 'HDN', 'KHDN', 'Yampa Valley Airport (Yampa Valley Regional)', 'P-N', '136600', NULL, '0'),
#     ('Montrose', 'MTJ', 'MTJ', 'KMTJ', 'Montrose Regional Airport', 'P-N', '85868', NULL, '0'),
#     ('Telluride', 'TEX', 'TEX', 'KTEX', 'Telluride Regional Airport', 'P-N', '13325', NULL, '0'),
#     ('New Haven', 'HVN', 'HVN', 'KHVN', 'Tweed New Haven Regional Airport', 'P-N', '33988', NULL, '0'),
#     ('Windsor Locks', 'BDL', 'BDL', 'KBDL', 'Bradley International Airport', 'P-M', '3006362', 'MIA', '0'),
#     ('Daytona Beach', 'DAB', 'DAB', 'KDAB', 'Daytona Beach International Airport', 'P-N', '282784', NULL, '0'),
#     ('Fort Lauderdale', 'FLL', 'FLL', 'KFLL', 'Fort Lauderdale-Hollywood International Airport', 'P-L', '11020091', 'MIA', '0'),
#     ('Fort Myers', 'RSW', 'RSW', 'KRSW', 'Southwest Florida International Airport', 'P-M', '3770681', 'MIA', '0'),
#     ('Gainesville', 'GNV', 'GNV', 'KGNV', 'Gainesville Regional Airport', 'P-N', '136623', NULL, '0'),
#     ('Jacksonville', 'JAX', 'JAX', 'KJAX', 'Jacksonville International Airport', 'P-M', '2965973', 'MIA', '0'),
#     ('Key West', 'EYW', 'EYW', 'KEYW', 'Key West International Airport', 'P-N', '231339', NULL, '0'),
#     ('Melbourne', 'MLB', 'MLB', 'KMLB', 'Melbourne International Airport', 'P-N', '145117', NULL, '0'),
#     ('Miami', 'MIA', 'MIA', 'KMIA', 'Miami International Airport', 'P-L', '16377488', NULL, '1'),
#     ('Orlando', 'MCO', 'MCO', 'KMCO', 'Orlando International Airport', 'P-L', '17288480', 'MIA', '0'),
#     ('Orlando', 'SFB', 'SFB', 'KSFB', 'Orlando Sanford International Airport', 'P-S', '927188', 'MIA', '0'),
#     ('Pensacola', 'PNS', 'PNS', 'KPNS', 'Pensacola Gulf Coast Regional Airport', 'P-S', '771917', 'MIA', '0'),
#     ('Sarasota / Bradenton', 'SRQ', 'SRQ', 'KSRQ', 'Sarasota-Bradenton International Airport', 'P-S', '753126', 'MIA', '0'),
#     ('St. Petersburg', 'PIE', 'PIE', 'KPIE', 'St. Petersburg-Clearwater International Airport', 'P-N', '363725', NULL, '0'),
#     ('Tallahassee', 'TLH', 'TLH', 'KTLH', 'Tallahassee Regional Airport', 'P-S', '399094', 'MIA', '0'),
#     ('Tampa', 'TPA', 'TPA', 'KTPA', 'Tampa International Airport', 'P-L', '8871917', 'MIA', '0'),
#     ('Valparaiso', 'VPS', 'VPS', 'KVPS', 'Northwest Florida Regional Airport / Eglin Air Force Base', 'P-N', '373808', NULL, '0'),
#     ('West Palm Beach', 'PBI', 'PBI', 'KPBI', 'Palm Beach International Airport', 'P-M', '3232009', 'MIA', '0'),
#     ('Albany', 'ABY', 'ABY', 'KABY', 'Southwest Georgia Regional Airport', 'P-N', '39200', NULL, '0'),
#     ('Atlanta', 'ATL', 'ATL', 'KATL', 'Hartsfield-Jackson Atlanta International Airport', 'P-L', '43761280', 'MIA', '0'),
#     ('Augusta', 'AGS', 'AGS', 'KAGS', 'Augusta Regional Airport at Bush Field', 'P-N', '176097', NULL, '0'),
#     ('Brunswick', 'BQK', 'BQK', 'KBQK', 'Brunswick Golden Isles Airport', 'P-N', '29594', NULL, '0'),
#     ('Columbus', 'CSG', 'CSG', 'KCSG', 'Columbus Airport', 'P-N', '51288', NULL, '0'),
#     ('Macon', 'MCN', 'MCN', 'KMCN', 'Middle Georgia Regional Airport', 'P-N', '10029', NULL, '0'),
#     ('Savannah', 'SAV', 'SAV', 'KSAV', 'Savannah/Hilton Head International Airport', 'P-S', '959037', 'MIA', '0'),
#     ('Valdosta', 'VLD', 'VLD', 'KVLD', 'Valdosta Regional Airport', 'P-N', '38269', NULL, '0'),
#     ('Hilo', 'ITO', 'ITO', 'PHTO', 'Hilo International Airport', 'P-S', '648263', 'LAX', '0'),
#     ('Honolulu', 'HNL', 'HNL', 'PHNL', 'Honolulu International Airport / Hickam AFB', 'P-L', '9013440', 'LAX', '0'),
#     ('Kahului', 'OGG', 'OGG', 'PHOG', 'Kahului Airport', 'P-M', '2652335', 'MIA', '0'),
#     ('Kailua/Kona', 'KOA', 'KOA', 'PHKO', 'Kona International Airport at Keahole', 'P-S', '1332667', 'LAX', '0'),
#     ('Kaunakakai', 'MKK', 'MKK', 'PHMK', 'Molokai Airport', 'P-N', '89468', NULL, '0'),
#     ('Lanai City', 'LNY', 'LNY', 'PHNY', 'Lanai Airport', 'P-N', '52075', NULL, '0'),
#     (e'Lihue (Lihu\'e)', 'LIH', 'LIH', 'PHLI', e'Lihue Airport (Lihu\'e Airport)', 'P-S', '1287696', 'LAX', '0'),
#     ('Boise', 'BOI', 'BOI', 'KBOI', 'Boise Airport (Boise Air Terminal) (Gowen Field)', 'P-S', '1574210', 'ORD', '0'),
#     ('Hailey', 'SUN', 'SUN', 'KSUN', 'Friedman Memorial Airport', 'P-N', '64233', NULL, '0'),
#     ('Idaho Falls', 'IDA', 'IDA', 'KIDA', 'Idaho Falls Regional Airport (Fanning Field)', 'P-N', '148584', NULL, '0'),
#     ('Lewiston', 'LWS', 'LWS', 'KLWS', 'Lewiston-Nez Perce County Airport', 'P-N', '64379', NULL, '0'),
#     ('Pocatello / Arbon Valley', 'PIH', 'PIH', 'KPIH', 'Pocatello Regional Airport', 'P-N', '25756', NULL, '0'),
#     ('Twin Falls', 'TWF', 'TWF', 'KTWF', 'Magic Valley Regional Airport (Joslin Field)', 'P-N', '29606', NULL, '0'),
#     ('Belleville', 'BLV', 'BLV', 'KBLV', 'MidAmerica St. Louis Airport / Scott Air Force Base', 'P-N', '27002', NULL, '0'),
#     ('Bloomington / Normal', 'BMI', 'BMI', 'KBMI', 'Central Illinois Regional Airport at Bloomington-Normal', 'P-N', '262846', NULL, '0'),
#     ('Champaign / Urbana', 'CMI', 'CMI', 'KCMI', 'University of Illinois - Willard Airport', 'P-N', '98225', NULL, '0'),
#     ('Chicago', 'ORD', 'ORD', 'KORD', e'Chicago O\'Hare International Airport', 'P-L', '33683991', NULL, '1'),
#     ('Moline', 'MLI', 'MLI', 'KMLI', 'Quad City International Airport', 'P-S', '476532', 'ORD', '0'),
#     ('Rockford', 'RFD', 'RFD', 'KRFD', 'Chicago Rockford International Airport', 'P-N', '110151', NULL, '0'),
#     ('Springfield', 'SPI', 'SPI', 'KSPI', 'Abraham Lincoln Capital Airport', 'P-N', '56771', NULL, '0'),
#     ('Evansville', 'EVV', 'EVV', 'KEVV', 'Evansville Regional Airport', 'P-N', '193349', NULL, '0'),
#     ('Fort Wayne', 'FWA', 'FWA', 'KFWA', 'Fort Wayne International Airport', 'P-N', '282449', NULL, '0'),
#     ('Indianapolis', 'IND', 'IND', 'KIND', 'Indianapolis International Airport', 'P-M', '4061450', 'MIA', '0'),
#     ('South Bend', 'SBN', 'SBN', 'KSBN', 'South Bend Regional Airport', 'P-S', '357168', 'ORD', '0'),
#     ('Cedar Rapids', 'CID', 'CID', 'KCID', 'The Eastern Iowa Airport', 'P-S', '499600', 'ORD', '0'),
#     ('Des Moines', 'DSM', 'DSM', 'KDSM', 'Des Moines International Airport', 'P-S', '919990', 'ORD', '0'),
#     ('Dubuque', 'DBQ', 'DBQ', 'KDBQ', 'Dubuque Regional Airport', 'P-N', '42870', NULL, '0'),
#     ('Mason City', 'MCW', 'MCW', 'KMCW', 'Mason City Municipal Airport', 'P-N', '11678', NULL, '0'),
#     ('Sioux City', 'SUX', 'SUX', 'KSUX', 'Sioux Gateway Airport (Col. Bud Day Field)', 'P-N', '49871', NULL, '0'),
#     ('Waterloo', 'ALO', 'ALO', 'KALO', 'Waterloo Regional Airport', 'P-N', '26831', NULL, '0'),
#     ('Garden City', 'GCK', 'GCK', 'KGCK', 'Garden City Regional Airport', 'P-N', '11453', NULL, '0'),
#     ('Manhattan', 'MHK', 'MHK', 'KMHK', 'Manhattan Regional Airport', 'P-N', '16489', NULL, '0'),
#     ('Wichita', 'ICT', 'ICT', 'KICT', 'Wichita Mid-Continent Airport', 'P-S', '780756', 'ORD', '0'),
#     ('Covington', 'CVG', 'CVG', 'KCVG', 'Cincinnati/Northern Kentucky International Airport', 'P-L', '5194214', 'ORD', '0'),
#     ('Lexington', 'LEX', 'LEX', 'KLEX', 'Blue Grass Airport', 'P-S', '450464', 'MIA', '0'),
#     ('Louisville', 'SDF', 'SDF', 'KSDF', 'Louisville International Airport (Standiford Field)', 'P-S', '1622804', 'MIA', '0'),
#     ('Paducah', 'PAH', 'PAH', 'KPAH', 'Barkley Regional Airport', 'P-N', '18452', NULL, '0'),
#     ('Alexandria', 'AEX', 'AEX', 'KAEX', 'Alexandria International Airport', 'P-N', '179129', NULL, '0'),
#     ('Baton Rouge', 'BTR', 'BTR', 'KBTR', 'Baton Rouge Metropolitan Airport (Ryan Field)', 'P-S', '382687', 'MIA', '0'),
#     ('Lafayette', 'LFT', 'LFT', 'KLFT', 'Lafayette Regional Airport', 'P-N', '220211', NULL, '0'),
#     ('Lake Charles', 'LCH', 'LCH', 'KLCH', 'Lake Charles Regional Airport', 'P-N', '65340', NULL, '0'),
#     ('Monroe', 'MLU', 'MLU', 'KMLU', 'Monroe Regional Airport', 'P-N', '100419', NULL, '0'),
#     ('New Orleans', 'MSY', 'MSY', 'KMSY', 'Louis Armstrong New Orleans International Airport', 'P-M', '4088037', 'DFW', '0'),
#     ('Shreveport', 'SHV', 'SHV', 'KSHV', 'Shreveport Regional Airport', 'P-N', '237945', NULL, '0'),
#     ('Bangor', 'BGR', 'BGR', 'KBGR', 'Bangor International Airport', 'P-S', '355508', 'ORD', '0'),
#     ('Bar Harbor', 'BHB', 'BHB', 'KBHB', 'Hancock County-Bar Harbor Airport', 'P-N', '10562', NULL, '0'),
#     ('Portland', 'PWM', 'PWM', 'KPWM', 'Portland International Jetport', 'P-S', '876102', 'LAX', '0'),
#     ('Presque Isle', 'PQI', 'PQI', 'KPQI', 'Northern Maine Regional Airport at Presque Isle', 'P-N', '13385', NULL, '0'),
#     ('Rockland', 'RKD', 'RKD', 'KRKD', 'Knox County Regional Airport', 'P-N', '13866', NULL, '0'),
#     ('Baltimore / Glen Burnie', 'BWI', 'BWI', 'KBWI', 'Baltimore/Washington International Thurgood Marshall Airport', 'P-L', '10215225', 'ORD', '0'),
#     ('Salisbury', 'SBY', 'SBY', 'KSBY', 'Salisbury-Ocean City Wicomico Regional Airport', 'P-N', '58863', NULL, '0'),
#     ('Boston', 'BOS', 'BOS', 'KBOS', 'Gen. Edward Lawrence Logan International Airport', 'P-L', '12820489', 'JFK', '0'),
#     ('Hyannis', 'HYA', 'HYA', 'KHYA', 'Barnstable Municipal Airport (Boardman/Polando Field)', 'P-N', '191906', NULL, '0'),
#     ('Nantucket', 'ACK', 'ACK', 'KACK', 'Nantucket Memorial Airport', 'P-N', '258214', NULL, '0'),
#     ('New Bedford', 'EWB', 'EWB', 'KEWB', 'New Bedford Regional Airport', 'P-N', '13908', NULL, '0'),
#     ('Provincetown', 'PVC', 'PVC', 'KPVC', 'Provincetown Municipal Airport', 'P-N', '11468', NULL, '0'),
#     ('Vineyard Haven', 'MVY', 'MVY', 'KMVY', e'Martha\'s Vineyard Airport', 'P-N', '45002', NULL, '0'),
#     ('Charlevoix', 'CVX', 'CVX', 'KCVX', 'Charlevoix Municipal Airport', 'P-N', '17854', NULL, '0'),
#     ('Detroit / Romulus', 'DTW', 'DTW', 'KDTW', 'Detroit Metropolitan Wayne County Airport', 'P-L', '16998174', 'ORD', '0'),
#     ('Flint', 'FNT', 'FNT', 'KFNT', 'Bishop International Airport', 'P-S', '526492', 'LAX', '0'),
#     ('Grand Rapids', 'GRR', 'GRR', 'KGRR', 'Gerald R. Ford International Airport', 'P-S', '902925', 'LAX', '0'),
#     ('Hancock / Calumet', 'CMX', 'CMX', 'KCMX', 'Houghton County Memorial Airport', 'P-N', '25354', NULL, '0'),
#     ('Kalamazoo / Battle Creek', 'AZO', 'AZO', 'KAZO', 'Kalamazoo/Battle Creek International Airport', 'P-N', '168687', NULL, '0'),
#     ('Lansing', 'LAN', 'LAN', 'KLAN', 'Capital Region International Airport (was Lansing Capital City)', 'P-N', '217437', NULL, '0'),
#     ('Marquette / Gwinn', 'SAW', 'MQT', 'KSAW', 'Sawyer International Airport', 'P-N', '56172', NULL, '0'),
#     ('Muskegon', 'MKG', 'MKG', 'KMKG', 'Muskegon County Airport', 'P-N', '30051', NULL, '0'),
#     ('Pellston', 'PLN', 'PLN', 'KPLN', 'Pellston Regional Airport of Emmet County', 'P-N', '26222', NULL, '0'),
#     ('Saginaw', 'MBS', 'MBS', 'KMBS', 'MBS International Airport', 'P-N', '162703', NULL, '0'),
#     ('Sault Ste. Marie', 'CIU', 'CIU', 'KCIU', 'Chippewa County International Airport', 'P-N', '13269', NULL, '0'),
#     ('Traverse City', 'TVC', 'TVC', 'KTVC', 'Cherry Capital Airport', 'P-N', '183357', NULL, '0'),
#     ('Bemidji', 'BJI', 'BJI', 'KBJI', 'Bemidji Regional Airport', 'P-N', '22007', NULL, '0'),
#     ('Brainerd', 'BRD', 'BRD', 'KBRD', 'Brainerd Lakes Regional Airport', 'P-N', '16665', NULL, '0'),
#     ('Duluth', 'DLH', 'DLH', 'KDLH', 'Duluth International Airport', 'P-N', '147793', NULL, '0'),
#     ('International Falls', 'INL', 'INL', 'KINL', 'Falls International Airport', 'P-N', '16590', NULL, '0'),
#     ('Minneapolis', 'MSP', 'MSP', 'KMSP', 'Minneapolis-St. Paul International Airport (Wold-Chamberlain Field)', 'P-L', '16369324', NULL, '0'),
#     ('Rochester', 'RST', 'RST', 'KRST', 'Rochester International Airport', 'P-N', '151250', NULL, '0'),
#     ('St. Cloud', 'STC', 'STC', 'KSTC', 'St. Cloud Regional Airport', 'P-N', '20161', NULL, '0'),
#     ('Columbus / West Point / Starkville', 'GTR', 'GTR', 'KGTR', 'Golden Triangle Regional Airport', 'P-N', '36329', NULL, '0'),
#     ('Gulfport / Biloxi', 'GPT', 'GPT', 'KGPT', 'Gulfport-Biloxi International Airport', 'P-S', '461072', 'MIA', '0'),
#     ('Hattiesburg / Laurel', 'PIB', 'PIB', 'KPIB', 'Hattiesburg-Laurel Regional Airport', 'P-N', '13766', NULL, '0'),
#     ('Jackson', 'JAN', 'JAN', 'KJAN', 'Jackson-Evers International Airport', 'P-S', '618373', 'MIA', '0'),
#     ('Meridian', 'MEI', 'MEI', 'KMEI', 'Meridian Regional Airport (Key Field)', 'P-N', '16871', NULL, '0'),
#     ('Tunica', 'UTA', 'UTM', 'KUTA', 'Tunica Municipal Airport', 'P-N', '65907', NULL, '0'),
#     ('Tupelo', 'TUP', 'TUP', 'KTUP', 'Tupelo Regional Airport (C.D. Lemons Field)', 'P-N', '12749', NULL, '0'),
#     ('Columbia', 'COU', 'COU', 'KCOU', 'Columbia Regional Airport', 'P-N', '12719', NULL, '0'),
#     ('Kansas City', 'MCI', 'MCI', 'KMCI', 'Kansas City International Airport', 'P-M', '5386242', 'DFW', '0'),
#     ('Springfield', 'SGF', 'SGF', 'KSGF', 'Springfield-Branson National Airport', 'P-S', '779995', 'MIA', '0'),
#     ('St. Louis', 'STL', 'STL', 'KSTL', 'Lambert-St. Louis International Airport', 'P-M', '6740468', 'ORD', '0'),
#     ('Billings', 'BIL', 'BIL', 'KBIL', 'Billings Logan International Airport', 'P-S', '422494', 'JFK', '0'),
#     ('Bozeman', 'BZN', 'BZN', 'KBZN', 'Gallatin Field Airport', 'P-N', '349550', NULL, '0'),
#     ('Butte', 'BTM', 'BTM', 'KBTM', 'Bert Mooney Airport', 'P-N', '30431', NULL, '0'),
#     ('Great Falls', 'GTF', 'GTF', 'KGTF', 'Great Falls International Airport', 'P-N', '143811', NULL, '0'),
#     ('Helena', 'HLN', 'HLN', 'KHLN', 'Helena Regional Airport', 'P-N', '85649', NULL, '0'),
#     ('Kalispell', 'GPI', 'FCA', 'KGPI', 'Glacier Park International Airport', 'P-N', '186450', NULL, '0'),
#     ('Missoula', 'MSO', 'MSO', 'KMSO', 'Missoula International Airport', 'P-N', '288071', NULL, '0'),
#     ('Omaha', 'OMA', 'OMA', 'KOMA', 'Eppley Airfield', 'P-M', '2083973', 'ORD', '0'),
#     ('Lincoln', 'LNK', 'LNK', 'KLNK', 'Lincoln Airport (was Lincoln Municipal)', 'P-N', '142507', NULL, '0'),
#     ('Grand Island', 'GRI', 'GRI', 'KGRI', 'Central Nebraska Regional Airport', 'P-N', '20136', NULL, '0'),
#     ('Scottsbluff', 'BFF', 'BFF', 'KBFF', 'Western Nebraska Regional Airport (William B. Heilig Field)', 'P-N', '9221', NULL, '0'),
#     ('Boulder City', 'BVU', 'BLD', 'KBVU', 'Boulder City Municipal Airport', 'P-N', '300553', NULL, '0'),
#     ('Elko', 'EKO', 'EKO', 'KEKO', 'Elko Regional Airport (J.C. Harris Field)', 'P-N', '25523', NULL, '0'),
#     ('Las Vegas', 'LAS', 'LAS', 'KLAS', 'McCarran International Airport', 'P-L', '21024443', 'DFW', '0'),
#     ('North Las Vegas', 'VGT', 'VGT', 'KVGT', 'North Las Vegas Airport', 'P-N', '67389', NULL, '0'),
#     ('Reno', 'RNO', 'RNO', 'KRNO', 'Reno-Tahoe International Airport', 'P-M', '2150816', 'ORD', '0'),
#     ('Manchester', 'MHT', 'MHT', 'KMHT', 'Manchester-Boston Regional Airport', 'P-M', '1834875', 'JFK', '0'),
#     ('Portsmouth', 'PSM', 'PSM', 'KPSM', 'Portsmouth International Airport at Pease', 'P-N', '49962', NULL, '0'),
#     ('Atlantic City', 'ACY', 'ACY', 'KACY', 'Atlantic City International Airport', 'P-S', '527873', 'JFK', '0'),
#     ('Newark', 'EWR', 'EWR', 'KEWR', 'Newark Liberty International Airport', 'P-L', '17599578', 'JFK', '0'),
#     ('Albuquerque', 'ABQ', 'ABQ', 'KABQ', 'Albuquerque International Sunport', 'P-M', '3158971', 'DFW', '0'),
#     ('Farmington', 'FMN', 'FMN', 'KFMN', 'Four Corners Regional Airport', 'P-N', '17044', NULL, '0'),
#     ('Albany', 'ALB', 'ALB', 'KALB', 'Albany International Airport', 'P-S', '1365854', 'JFK', '0'),
#     ('Binghamton', 'BGM', 'BGM', 'KBGM', 'Greater Binghamton Airport (Edwin A. Link Field)', 'P-N', '125368', NULL, '0'),
#     ('Buffalo', 'BUF', 'BUF', 'KBUF', 'Buffalo Niagara International Airport', 'P-M', '2744501', 'JFK', '0'),
#     ('Elmira / Corning', 'ELM', 'ELM', 'KELM', 'Elmira/Corning Regional Airport', 'P-N', '104508', NULL, '0'),
#     ('Islip', 'ISP', 'ISP', 'KISP', 'Long Island MacArthur Airport', 'P-S', '1048768', 'JFK', '0'),
#     ('Ithaca', 'ITH', 'ITH', 'KITH', 'Ithaca Tompkins Regional Airport', 'P-N', '91866', NULL, '0'),
#     ('New York', 'JFK', 'JFK', 'KJFK', 'John F. Kennedy International Airport', 'P-L', '23620948', NULL, '1'),
#     ('New York', 'LGA', 'LGA', 'KLGA', 'LaGuardia Airport (and Marine Air Terminal)', 'P-L', '11567586', 'ORD', '0'),
#     ('Newburgh', 'SWF', 'SWF', 'KSWF', 'Stewart International Airport', 'P-N', '392464', NULL, '0'),
#     ('Rochester', 'ROC', 'ROC', 'KROC', 'Greater Rochester International Airport', 'P-S', '1349694', 'JFK', '0'),
#     ('Syracuse', 'SYR', 'SYR', 'KSYR', 'Syracuse Hancock International Airport', 'P-S', '1105143', 'JFK', '0'),
#     ('White Plains', 'HPN', 'HPN', 'KHPN', 'Westchester County Airport', 'P-S', '904482', 'JFK', '0'),
#     ('Asheville', 'AVL', 'AVL', 'KAVL', 'Asheville Regional Airport', 'P-N', '682306', NULL, '0'),
#     ('Charlotte', 'CLT', 'CLT', 'KCLT', 'Charlotte/Douglas International Airport', 'P-L', '18281425', 'JFK', '0'),
#     ('Fayetteville', 'FAY', 'FAY', 'KFAY', 'Fayetteville Regional Airport (Grannis Field)', 'P-N', '202597', NULL, '0'),
#     ('Greensboro', 'GSO', 'GSO', 'KGSO', 'Piedmont Triad International Airport', 'P-S', '863745', 'JFK', '0'),
#     ('Greenville', 'PGV', 'PGV', 'KPGV', 'Pitt-Greenville Airport', 'P-N', '52287', NULL, '0'),
#     ('Jacksonville', 'OAJ', 'OAJ', 'KOAJ', 'Albert J. Ellis Airport', 'P-N', '126947', NULL, '0'),
#     ('New Bern', 'EWN', 'EWN', 'KEWN', 'Coastal Carolina Regional Airport (was Craven Co. Regional)', 'P-N', '111184', NULL, '0'),
#     ('Raleigh', 'RDU', 'RDU', 'KRDU', 'Raleigh-Durham International Airport', 'P-M', '4868492', 'JFK', '0'),
#     ('Wilmington', 'ILM', 'ILM', 'KILM', 'Wilmington International Airport', 'P-N', '469993', NULL, '0'),
#     ('Bismarck', 'BIS', 'BIS', 'KBIS', 'Bismarck Municipal Airport', 'P-N', '178005', NULL, '0'),
#     ('Fargo', 'FAR', 'FAR', 'KFAR', 'Hector International Airport', 'P-N', '326941', NULL, '0'),
#     ('Grand Forks', 'GFK', 'GFK', 'KGFK', 'Grand Forks International Airport', 'P-N', '88093', NULL, '0'),
#     ('Minot', 'MOT', 'MOT', 'KMOT', 'Minot International Airport', 'P-N', '71595', NULL, '0'),
#     ('Akron', 'CAK', 'CAK', 'KCAK', 'Akron-Canton Regional Airport', 'P-S', '715367', 'JFK', '0'),
#     ('Cleveland', 'CLE', 'CLE', 'KCLE', 'Cleveland-Hopkins International Airport', 'P-M', '4704329', 'DWF', '0'),
#     ('Columbus', 'CMH', 'CMH', 'KCMH', 'Port Columbus International Airport', 'P-M', '3096515', 'JFK', '0'),
#     ('Dayton', 'DAY', 'DAY', 'KDAY', 'James M. Cox Dayton International Airport', 'P-S', '1240848', 'MIA', '0'),
#     ('Toledo', 'TOL', 'TOL', 'KTOL', 'Toledo Express Airport', 'P-N', '93669', NULL, '0'),
#     ('Youngstown / Warren', 'YNG', 'YNG', 'KYNG', 'Youngstown-Warren Regional Airport / Youngstown ARS', 'P-N', '17391', NULL, '0'),
#     ('Lawton', 'LAW', 'LAW', 'KLAW', 'Lawton-Fort Sill Regional Airport', 'P-N', '77533', NULL, '0'),
#     ('Oklahoma City', 'OKC', 'OKC', 'KOKC', 'Will Rogers World Airport', 'P-S', '1838709', 'ORD', '0'),
#     ('Tulsa', 'TUL', 'TUL', 'KTUL', 'Tulsa International Airport', 'P-S', '1606622', 'MIA', '0'),
#     ('Eugene', 'EUG', 'EUG', 'KEUG', 'Eugene Airport (Mahlon Sweet Field)', 'P-N', '358819', NULL, '0'),
#     ('Klamath Falls', 'LMT', 'LMT', 'KLMT', 'Klamath Falls Airport (Kingsley Field)', 'P-N', '26970', NULL, '0'),
#     ('Medford', 'MFR', 'MFR', 'KMFR', 'Rogue Valley International-Medford Airport', 'P-N', '287688', NULL, '0'),
#     ('North Bend', 'OTH', 'OTH', 'KOTH', 'Southwest Oregon Regional Airport (was North Bend Municipal)', 'P-N', '35458', NULL, '0'),
#     ('Portland', 'PDX', 'PDX', 'KPDX', 'Portland International Airport', 'P-M', '7090526', 'LAX', '0'),
#     ('Redmond', 'RDM', 'RDM', 'KRDM', 'Redmond Municipal Airport (Roberts Field)', 'P-N', '235192', NULL, '0'),
#     ('Allentown', 'ABE', 'ABE', 'KABE', 'Lehigh Valley International Airport', 'P-S', '392039', 'MIA', '0'),
#     ('Erie', 'ERI', 'ERI', 'KERI', 'Erie International Airport (Tom Ridge Field)', 'P-N', '124667', NULL, '0'),
#     ('Harrisburg / Middletown', 'MDT', 'MDT', 'KMDT', 'Harrisburg International Airport', 'P-S', '635627', 'ORD', '0'),
#     ('Latrobe', 'LBE', 'LBE', 'KLBE', 'Arnold Palmer Regional Airport', 'P-N', '18946', NULL, '0'),
#     ('Philadelphia', 'PHL', 'PHL', 'KPHL', 'Philadelphia International Airport', 'P-L', '15586852', 'JFK', '0'),
#     ('Pittsburgh', 'PIT', 'PIT', 'KPIT', 'Pittsburgh International Airport', 'P-M', '4292546', 'JFK', '0'),
#     ('State College', 'UNV', 'SCE', 'KUNV', 'University Park Airport', 'P-N', '133777', NULL, '0'),
#     ('Wilkes-Barre / Scranton', 'AVP', 'AVP', 'KAVP', 'Wilkes-Barre/Scranton International Airport', 'P-N', '219745', NULL, '0'),
#     ('Williamsport', 'IPT', 'IPT', 'KIPT', 'Williamsport Regional Airport', 'P-N', '23901', NULL, '0'),
#     ('Providence / Warwick', 'PVD', 'PVD', 'KPVD', 'Theodore Francis Green State Airport', 'P-M', '2342593', 'JFK', '0'),
#     ('Charleston', 'CHS', 'CHS', 'KCHS', 'Charleston International Airport / Charleston AFB', 'P-S', '1174667', 'ORD', '0'),
#     ('Columbia', 'CAE', 'CAE', 'KCAE', 'Columbia Metropolitan Airport', 'P-S', '565938', 'ORD', '0'),
#     ('Florence', 'FLO', 'FLO', 'KFLO', 'Florence Regional Airport', 'P-N', '64835', NULL, '0'),
#     ('Greer', 'GSP', 'GSP', 'KGSP', 'Greenville-Spartanburg International Airport (Roger Milliken Field)', 'P-S', '699805', 'ORD', '0'),
#     ('Hilton Head Island', 'HXD', 'HHH', 'KHXD', 'Hilton Head Airport', 'P-N', '79912', NULL, '0'),
#     ('Myrtle Beach', 'MYR', 'MYR', 'KMYR', 'Myrtle Beach International Airport', 'P-S', '705430', 'ORD', '0'),
#     ('Aberdeen', 'ABR', 'ABR', 'KABR', 'Aberdeen Regional Airport', 'P-N', '23225', NULL, '0'),
#     ('Pierre', 'PIR', 'PIR', 'KPIR', 'Pierre Regional Airport', 'P-N', '15983', NULL, '0'),
#     ('Rapid City', 'RAP', 'RAP', 'KRAP', 'Rapid City Regional Airport', 'P-N', '273151', NULL, '0'),
#     ('Sioux Falls', 'FSD', 'FSD', 'KFSD', 'Sioux Falls Regional Airport (Joe Foss Field)', 'P-S', '367874', 'ORD', '0'),
#     ('Bristol / Johnson City / Kingsport', 'TRI', 'TRI', 'KTRI', 'Tri-Cities Regional Airport (Tri-Cities Regional TN/VA)', 'P-N', '202730', NULL, '0'),
#     ('Chattanooga', 'CHA', 'CHA', 'KCHA', 'Chattanooga Metropolitan Airport (Lovell Field)', 'P-N', '300796', NULL, '0'),
#     ('Knoxville', 'TYS', 'TYS', 'KTYS', 'McGhee Tyson Airport', 'P-S', '839266', 'DFW', '0'),
#     ('Memphis', 'MEM', 'MEM', 'KMEM', 'Memphis International Airport', 'P-M', '5376818', 'ORD', '0'),
#     ('Nashville', 'BNA', 'BNA', 'KBNA', 'Nashville International Airport (Berry Field)', 'P-M', '4648000', 'ORD', '0'),
#     ('Abilene', 'ABI', 'ABI', 'KABI', 'Abilene Regional Airport', 'P-N', '73605', NULL, '0'),
#     ('Amarillo', 'AMA', 'AMA', 'KAMA', 'Rick Husband Amarillo International Airport', 'P-S', '394593', 'DFW', '0'),
#     ('Austin', 'AUS', 'AUS', 'KAUS', 'Austin-Bergstrom International Airport', 'P-M', '4201136', 'DFW', '0'),
#     ('Beaumont / Port Arthur', 'BPT', 'BPT', 'KBPT', 'Southeast Texas Regional Airport', 'P-N', '17394', NULL, '0'),
#     ('Brownsville', 'BRO', 'BRO', 'KBRO', 'Brownsville/South Padre Island International Airport', 'P-N', '84401', NULL, '0'),
#     ('College Station', 'CLL', 'CLL', 'KCLL', 'Easterwood Airport (Easterwood Field)', 'P-N', '72188', NULL, '0'),
#     ('Corpus Christi / Kingsville', 'CRP', 'CRP', 'KCRP', 'Corpus Christi International Airport', 'P-N', '339193', NULL, '0'),
#     ('Dallas', 'DAL', 'DAL', 'KDAL', 'Dallas Love Field', 'P-M', '3783407', 'DFW', '0'),
#     ('Dallas-Fort Worth', 'DFW', 'DFW', 'KDFW', 'Dallas-Fort Worth International Airport', 'P-L', '27100656', NULL, '1'),
#     ('Del Rio', 'DRT', 'DRT', 'KDRT', 'Del Rio International Airport', 'P-N', '13180', NULL, '0'),
#     ('El Paso', 'ELP', 'ELP', 'KELP', 'El Paso International Airport', 'P-S', '1509093', 'DFW', '0'),
#     ('Fort Hood / Killeen / Temple', 'GRK', 'GRK', 'KGRK', 'Killeen-Fort Hood Regional Airport / Robert Gray Army Airfield', 'P-N', '243861', NULL, '0'),
#     ('Harlingen', 'HRL', 'HRL', 'KHRL', 'Valley International Airport', 'P-S', '373438', 'DFW', '0'),
#     ('Houston', 'IAH', 'IAH', 'KIAH', 'George Bush Intercontinental Airport', 'P-L', '19528627', 'DFW', '0'),
#     ('Houston', 'HOU', 'HOU', 'KHOU', 'William P. Hobby Airport', 'P-M', '4357835', 'DFW', '0'),
#     ('Laredo', 'LRD', 'LRD', 'KLRD', 'Laredo International Airport', 'P-N', '112520', NULL, '0'),
#     ('Longview', 'GGG', 'GGG', 'KGGG', 'East Texas Regional Airport', 'P-N', '21830', NULL, '0'),
#     ('Lubbock', 'LBB', 'LBB', 'KLBB', 'Lubbock Preston Smith International Airport', 'P-S', '508858', 'DFW', '0'),
#     ('McAllen', 'MFE', 'MFE', 'KMFE', 'McAllen-Miller International Airport', 'P-N', '344302', NULL, '0'),
#     ('Midland', 'MAF', 'MAF', 'KMAF', 'Midland International Airport', 'P-S', '445043', 'JFK', '0'),
#     ('San Angelo', 'SJT', 'SJT', 'KSJT', 'San Angelo Regional Airport (Mathis Field)', 'P-N', '56021', NULL, '0'),
#     ('San Antonio', 'SAT', 'SAT', 'KSAT', 'San Antonio International Airport', 'P-M', '3916320', 'DWF', '0'),
#     ('Tyler', 'TYR', 'TYR', 'KTYR', 'Tyler Pounds Regional Airport', 'P-N', '74357', NULL, '0'),
#     ('Waco', 'ACT', 'ACT', 'KACT', 'Waco Regional Airport', 'P-N', '61401', NULL, '0'),
#     ('Wichita Falls', 'SPS', 'SPS', 'KSPS', 'Wichita Falls Municipal Airport / Sheppard Air Force Base', 'P-N', '44296', NULL, '0'),
#     ('Salt Lake City', 'SLC', 'SLC', 'KSLC', 'Salt Lake City International Airport', 'P-L', '9993198', 'DFW', '0'),
#     ('Burlington', 'BTV', 'BTV', 'KBTV', 'Burlington International Airport', 'P-S', '747559', 'JFK', '0'),
#     ('Charlottesville', 'CHO', 'CHO', 'KCHO', 'Charlottesville-Albemarle Airport', 'P-N', '169843', NULL, '0'),
#     ('Lynchburg', 'LYH', 'LYH', 'KLYH', 'Lynchburg Regional Airport (Preston Glenn Field)', 'P-N', '55307', NULL, '0'),
#     ('Newport News', 'PHF', 'PHF', 'KPHF', 'Newport News/Williamsburg International Airport', 'P-S', '504292', 'JFK', '0'),
#     ('Norfolk', 'ORF', 'ORF', 'KORF', 'Norfolk International Airport', 'P-M', '1786594', 'ORD', '0'),
#     ('Richmond', 'RIC', 'RIC', 'KRIC', 'Richmond International Airport (Byrd Field)', 'P-S', '1733668', 'JFK', '0'),
#     ('Roanoke', 'ROA', 'ROA', 'KROA', 'Roanoke Regional Airport (Woodrum Field)', 'P-N', '315293', NULL, '0'),
#     ('Washington D.C. (Arlington County)', 'DCA', 'DCA', 'KDCA', 'Ronald Reagan Washington National Airport', 'P-L', '8704466', 'JFK', '0'),
#     ('Washington D.C. (Chantilly/Dulles)', 'IAD', 'IAD', 'KIAD', 'Washington Dulles International Airport', 'P-L', '11348775', 'JFK', '0'),
#     ('Bellingham', 'BLI', 'BLI', 'KBLI', 'Bellingham International Airport', 'P-N', '277281', NULL, '0'),
#     ('Friday Harbor', 'FHR', 'FRD', 'KFHR', 'Friday Harbor Airport', 'P-N', '13835', NULL, '0'),
#     ('Pasco', 'PSC', 'PSC', 'KPSC', 'Tri-Cities Airport', 'P-N', '242483', NULL, '0'),
#     ('Port Angeles', 'CLM', 'CLM', 'KCLM', 'William R. Fairchild International Airport', 'P-N', '12672', NULL, '0'),
#     ('Pullman/Moscow, Idaho', 'PUW', 'PUW', 'KPUW', 'Pullman-Moscow Regional Airport', 'P-N', '32108', NULL, '0'),
#     ('Seattle', 'BFI', 'BFI', 'KBFI', 'King County International Airport (Boeing Field)', 'P-N', '34597', NULL, '0'),
#     ('Seattle / Tacoma (SeaTac)', 'SEA', 'SEA', 'KSEA', 'Seattle-Tacoma International Airport', 'P-L', '15839504', 'LAX', '0'),
#     ('Spokane', 'GEG', 'GEG', 'KGEG', 'Spokane International Airport (Geiger Field)', 'P-S', '1691345', 'JFK', '0'),
#     ('Walla Walla', 'ALW', 'ALW', 'KALW', 'Walla Walla Regional Airport', 'P-N', '29672', NULL, '0'),
#     ('Wenatchee', 'EAT', 'EAT', 'KEAT', 'Pangborn Memorial Airport', 'P-N', '48275', NULL, '0'),
#     ('Yakima', 'YKM', 'YKM', 'KYKM', 'Yakima Air Terminal (McAllister Field)', 'P-N', '69835', NULL, '0'),
#     ('Charleston', 'CRW', 'CRW', 'KCRW', 'Yeager Airport', 'P-N', '243793', NULL, '0'),
#     ('Huntington', 'HTS', 'HTS', 'KHTS', 'Tri-State Airport (Milton J. Ferguson Field)', 'P-N', '83531', NULL, '0'),
#     ('Appleton', 'ATW', 'ATW', 'KATW', 'Outagamie County Regional Airport', 'P-N', '259340', NULL, '0'),
#     ('Eau Claire', 'EAU', 'EAU', 'KEAU', 'Chippewa Valley Regional Airport', 'P-N', '18762', NULL, '0'),
#     ('Green Bay', 'GRB', 'GRB', 'KGRB', 'Austin Straubel International Airport', 'P-S', '410348', 'JFK', '0'),
#     ('La Crosse', 'LSE', 'LSE', 'KLSE', 'La Crosse Municipal Airport', 'P-N', '111462', NULL, '0'),
#     ('Madison', 'MSN', 'MSN', 'KMSN', 'Dane County Regional Airport (Truax Field)', 'P-S', '728075', 'JFK', '0'),
#     ('Milwaukee', 'MKE', 'MKE', 'KMKE', 'General Mitchell International Airport', 'P-M', '3861333', 'ORD', '0'),
#     ('Mosinee', 'CWA', 'CWA', 'KCWA', 'Central Wisconsin Airport', 'P-N', '154312', NULL, '0'),
#     ('Rhinelander', 'RHI', 'RHI', 'KRHI', 'Rhinelander-Oneida County Airport', 'P-N', '26193', NULL, '0'),
#     ('Casper', 'CPR', 'CPR', 'KCPR', 'Casper/Natrona County International Airport', 'P-N', '74167', NULL, '0'),
#     ('Cheyenne', 'CYS', 'CYS', 'KCYS', 'Cheyenne Regional Airport (Jerry Olson Field)', 'P-N', '16697', NULL, '0'),
#     ('Cody', 'COD', 'COD', 'KCOD', 'Yellowstone Regional Airport', 'P-N', '25863', NULL, '0'),
#     ('Gillette', 'GCC', 'GCC', 'KGCC', 'Gillette-Campbell County Airport', 'P-N', '28232', NULL, '0'),
#     ('Jackson', 'JAC', 'JAC', 'KJAC', 'Jackson Hole Airport', 'P-N', '305566', NULL, '0'),
#     ('Laramie', 'LAR', 'LAR', 'KLAR', 'Laramie Regional Airport', 'P-N', '10371', NULL, '0'),
#     ('Riverton', 'RIW', 'RIW', 'KRIW', 'Riverton Regional Airport', 'P-N', '17035', NULL, '0'),
#     ('Rock Springs', 'RKS', 'RKS', 'KRKS', 'Rock Springs â€“ Sweetwater County Airport', 'P-N', '25541', NULL, '0'),
#     ('Sheridan', 'SHR', 'SHR', 'KSHR', 'Sheridan County Airport', 'P-N', '17710', NULL, '0');
# Out:
#  * postgresql://gpadmin:***@gpdb-sandbox:5432/gpadmin
# Done.
# Done.
# 349 rows affected.
# []

# %% [markdown]
# - pricing.time_dim

# %%
# %%sql
# DROP TABLE IF EXISTS pricing.time_dim CASCADE;
#
# CREATE TABLE pricing.time_dim (
# 	flight_date date,
# 	flight_month integer,
# 	flight_weekday integer,
# 	holiday_indicator integer
# ) DISTRIBUTED BY(flight_date);
#
# INSERT INTO pricing.time_dim
# 	(flight_date, flight_month, flight_weekday, holiday_indicator)
# VALUES
# 	('1/1/10','1','6','1'),
# 	('1/2/10','1','7','1'),
# 	('1/3/10','1','1','1'),
# 	('1/4/10','1','2','1'),
# 	('1/5/10','1','3','0'),
# 	('1/6/10','1','4','0'),
# 	('1/7/10','1','5','0'),
# 	('1/8/10','1','6','0'),
# 	('1/9/10','1','7','0'),
# 	('1/10/10','1','1','0'),
# 	('1/11/10','1','2','0'),
# 	('1/12/10','1','3','0'),
# 	('1/13/10','1','4','0'),
# 	('1/14/10','1','5','0'),
# 	('1/15/10','1','6','0'),
# 	('1/16/10','1','7','0'),
# 	('1/17/10','1','1','0'),
# 	('1/18/10','1','2','0'),
# 	('1/19/10','1','3','0'),
# 	('1/20/10','1','4','0'),
# 	('1/21/10','1','5','0'),
# 	('1/22/10','1','6','0'),
# 	('1/23/10','1','7','0'),
# 	('1/24/10','1','1','0'),
# 	('1/25/10','1','2','0'),
# 	('1/26/10','1','3','0'),
# 	('1/27/10','1','4','0'),
# 	('1/28/10','1','5','0'),
# 	('1/29/10','1','6','0'),
# 	('1/30/10','1','7','0'),
# 	('1/31/10','1','1','0'),
# 	('2/1/10','2','2','0'),
# 	('2/2/10','2','3','0'),
# 	('2/3/10','2','4','0'),
# 	('2/4/10','2','5','0'),
# 	('2/5/10','2','6','0'),
# 	('2/6/10','2','7','0'),
# 	('2/7/10','2','1','0'),
# 	('2/8/10','2','2','0'),
# 	('2/9/10','2','3','0'),
# 	('2/10/10','2','4','0'),
# 	('2/11/10','2','5','0'),
# 	('2/12/10','2','6','0'),
# 	('2/13/10','2','7','0'),
# 	('2/14/10','2','1','0'),
# 	('2/15/10','2','2','0'),
# 	('2/16/10','2','3','0'),
# 	('2/17/10','2','4','0'),
# 	('2/18/10','2','5','0'),
# 	('2/19/10','2','6','0'),
# 	('2/20/10','2','7','0'),
# 	('2/21/10','2','1','0'),
# 	('2/22/10','2','2','0'),
# 	('2/23/10','2','3','0'),
# 	('2/24/10','2','4','0'),
# 	('2/25/10','2','5','0'),
# 	('2/26/10','2','6','0'),
# 	('2/27/10','2','7','0'),
# 	('2/28/10','2','1','0'),
# 	('3/1/10','3','2','0'),
# 	('3/2/10','3','3','0'),
# 	('3/3/10','3','4','0'),
# 	('3/4/10','3','5','0'),
# 	('3/5/10','3','6','0'),
# 	('3/6/10','3','7','0'),
# 	('3/7/10','3','1','0'),
# 	('3/8/10','3','2','0'),
# 	('3/9/10','3','3','0'),
# 	('3/10/10','3','4','0'),
# 	('3/11/10','3','5','0'),
# 	('3/12/10','3','6','0'),
# 	('3/13/10','3','7','0'),
# 	('3/14/10','3','1','0'),
# 	('3/15/10','3','2','0'),
# 	('3/16/10','3','3','0'),
# 	('3/17/10','3','4','0'),
# 	('3/18/10','3','5','0'),
# 	('3/19/10','3','6','0'),
# 	('3/20/10','3','7','0'),
# 	('3/21/10','3','1','0'),
# 	('3/22/10','3','2','0'),
# 	('3/23/10','3','3','0'),
# 	('3/24/10','3','4','0'),
# 	('3/25/10','3','5','0'),
# 	('3/26/10','3','6','0'),
# 	('3/27/10','3','7','0'),
# 	('3/28/10','3','1','0'),
# 	('3/29/10','3','2','0'),
# 	('3/30/10','3','3','0'),
# 	('3/31/10','3','4','0'),
# 	('4/1/10','4','5','0'),
# 	('4/2/10','4','6','0'),
# 	('4/3/10','4','7','0'),
# 	('4/4/10','4','1','0'),
# 	('4/5/10','4','2','0'),
# 	('4/6/10','4','3','0'),
# 	('4/7/10','4','4','0'),
# 	('4/8/10','4','5','0'),
# 	('4/9/10','4','6','0'),
# 	('4/10/10','4','7','0'),
# 	('4/11/10','4','1','0'),
# 	('4/12/10','4','2','0'),
# 	('4/13/10','4','3','0'),
# 	('4/14/10','4','4','0'),
# 	('4/15/10','4','5','0'),
# 	('4/16/10','4','6','0'),
# 	('4/17/10','4','7','0'),
# 	('4/18/10','4','1','0'),
# 	('4/19/10','4','2','0'),
# 	('4/20/10','4','3','0'),
# 	('4/21/10','4','4','0'),
# 	('4/22/10','4','5','0'),
# 	('4/23/10','4','6','0'),
# 	('4/24/10','4','7','0'),
# 	('4/25/10','4','1','0'),
# 	('4/26/10','4','2','0'),
# 	('4/27/10','4','3','0'),
# 	('4/28/10','4','4','0'),
# 	('4/29/10','4','5','0'),
# 	('4/30/10','4','6','0'),
# 	('5/1/10','5','7','0'),
# 	('5/2/10','5','1','0'),
# 	('5/3/10','5','2','0'),
# 	('5/4/10','5','3','0'),
# 	('5/5/10','5','4','0'),
# 	('5/6/10','5','5','0'),
# 	('5/7/10','5','6','0'),
# 	('5/8/10','5','7','0'),
# 	('5/9/10','5','1','0'),
# 	('5/10/10','5','2','0'),
# 	('5/11/10','5','3','0'),
# 	('5/12/10','5','4','0'),
# 	('5/13/10','5','5','0'),
# 	('5/14/10','5','6','0'),
# 	('5/15/10','5','7','0'),
# 	('5/16/10','5','1','0'),
# 	('5/17/10','5','2','0'),
# 	('5/18/10','5','3','0'),
# 	('5/19/10','5','4','0'),
# 	('5/20/10','5','5','0'),
# 	('5/21/10','5','6','0'),
# 	('5/22/10','5','7','0'),
# 	('5/23/10','5','1','0'),
# 	('5/24/10','5','2','0'),
# 	('5/25/10','5','3','0'),
# 	('5/26/10','5','4','0'),
# 	('5/27/10','5','5','0'),
# 	('5/28/10','5','6','0'),
# 	('5/29/10','5','7','0'),
# 	('5/30/10','5','1','0'),
# 	('5/31/10','5','2','0'),
# 	('6/1/10','6','3','0'),
# 	('6/2/10','6','4','0'),
# 	('6/3/10','6','5','0'),
# 	('6/4/10','6','6','0'),
# 	('6/5/10','6','7','0'),
# 	('6/6/10','6','1','0'),
# 	('6/7/10','6','2','0'),
# 	('6/8/10','6','3','0'),
# 	('6/9/10','6','4','0'),
# 	('6/10/10','6','5','0'),
# 	('6/11/10','6','6','0'),
# 	('6/12/10','6','7','0'),
# 	('6/13/10','6','1','0'),
# 	('6/14/10','6','2','0'),
# 	('6/15/10','6','3','0'),
# 	('6/16/10','6','4','0'),
# 	('6/17/10','6','5','0'),
# 	('6/18/10','6','6','0'),
# 	('6/19/10','6','7','0'),
# 	('6/20/10','6','1','0'),
# 	('6/21/10','6','2','0'),
# 	('6/22/10','6','3','0'),
# 	('6/23/10','6','4','0'),
# 	('6/24/10','6','5','0'),
# 	('6/25/10','6','6','0'),
# 	('6/26/10','6','7','0'),
# 	('6/27/10','6','1','0'),
# 	('6/28/10','6','2','0'),
# 	('6/29/10','6','3','0'),
# 	('6/30/10','6','4','1'),
# 	('7/1/10','7','5','1'),
# 	('7/2/10','7','6','1'),
# 	('7/3/10','7','7','1'),
# 	('7/4/10','7','1','1'),
# 	('7/5/10','7','2','1'),
# 	('7/6/10','7','3','1'),
# 	('7/7/10','7','4','0'),
# 	('7/8/10','7','5','0'),
# 	('7/9/10','7','6','0'),
# 	('7/10/10','7','7','0'),
# 	('7/11/10','7','1','0'),
# 	('7/12/10','7','2','0'),
# 	('7/13/10','7','3','0'),
# 	('7/14/10','7','4','0'),
# 	('7/15/10','7','5','0'),
# 	('7/16/10','7','6','0'),
# 	('7/17/10','7','7','0'),
# 	('7/18/10','7','1','0'),
# 	('7/19/10','7','2','0'),
# 	('7/20/10','7','3','0'),
# 	('7/21/10','7','4','0'),
# 	('7/22/10','7','5','0'),
# 	('7/23/10','7','6','0'),
# 	('7/24/10','7','7','0'),
# 	('7/25/10','7','1','0'),
# 	('7/26/10','7','2','0'),
# 	('7/27/10','7','3','0'),
# 	('7/28/10','7','4','0'),
# 	('7/29/10','7','5','0'),
# 	('7/30/10','7','6','0'),
# 	('7/31/10','7','7','0'),
# 	('8/1/10','8','1','0'),
# 	('8/2/10','8','2','0'),
# 	('8/3/10','8','3','0'),
# 	('8/4/10','8','4','0'),
# 	('8/5/10','8','5','0'),
# 	('8/6/10','8','6','0'),
# 	('8/7/10','8','7','0'),
# 	('8/8/10','8','1','0'),
# 	('8/9/10','8','2','0'),
# 	('8/10/10','8','3','0'),
# 	('8/11/10','8','4','0'),
# 	('8/12/10','8','5','0'),
# 	('8/13/10','8','6','0'),
# 	('8/14/10','8','7','0'),
# 	('8/15/10','8','1','0'),
# 	('8/16/10','8','2','0'),
# 	('8/17/10','8','3','0'),
# 	('8/18/10','8','4','0'),
# 	('8/19/10','8','5','0'),
# 	('8/20/10','8','6','0'),
# 	('8/21/10','8','7','0'),
# 	('8/22/10','8','1','0'),
# 	('8/23/10','8','2','0'),
# 	('8/24/10','8','3','0'),
# 	('8/25/10','8','4','0'),
# 	('8/26/10','8','5','0'),
# 	('8/27/10','8','6','0'),
# 	('8/28/10','8','7','0'),
# 	('8/29/10','8','1','0'),
# 	('8/30/10','8','2','0'),
# 	('8/31/10','8','3','0'),
# 	('9/1/10','9','4','0'),
# 	('9/2/10','9','5','0'),
# 	('9/3/10','9','6','0'),
# 	('9/4/10','9','7','0'),
# 	('9/5/10','9','1','0'),
# 	('9/6/10','9','2','0'),
# 	('9/7/10','9','3','0'),
# 	('9/8/10','9','4','0'),
# 	('9/9/10','9','5','0'),
# 	('9/10/10','9','6','0'),
# 	('9/11/10','9','7','0'),
# 	('9/12/10','9','1','0'),
# 	('9/13/10','9','2','0'),
# 	('9/14/10','9','3','0'),
# 	('9/15/10','9','4','0'),
# 	('9/16/10','9','5','0'),
# 	('9/17/10','9','6','0'),
# 	('9/18/10','9','7','0'),
# 	('9/19/10','9','1','0'),
# 	('9/20/10','9','2','0'),
# 	('9/21/10','9','3','0'),
# 	('9/22/10','9','4','0'),
# 	('9/23/10','9','5','0'),
# 	('9/24/10','9','6','0'),
# 	('9/25/10','9','7','0'),
# 	('9/26/10','9','1','0'),
# 	('9/27/10','9','2','0'),
# 	('9/28/10','9','3','0'),
# 	('9/29/10','9','4','0'),
# 	('9/30/10','9','5','0'),
# 	('10/1/10','10','6','0'),
# 	('10/2/10','10','7','0'),
# 	('10/3/10','10','1','0'),
# 	('10/4/10','10','2','0'),
# 	('10/5/10','10','3','0'),
# 	('10/6/10','10','4','0'),
# 	('10/7/10','10','5','0'),
# 	('10/8/10','10','6','0'),
# 	('10/9/10','10','7','0'),
# 	('10/10/10','10','1','0'),
# 	('10/11/10','10','2','0'),
# 	('10/12/10','10','3','0'),
# 	('10/13/10','10','4','0'),
# 	('10/14/10','10','5','0'),
# 	('10/15/10','10','6','0'),
# 	('10/16/10','10','7','0'),
# 	('10/17/10','10','1','0'),
# 	('10/18/10','10','2','0'),
# 	('10/19/10','10','3','0'),
# 	('10/20/10','10','4','0'),
# 	('10/21/10','10','5','0'),
# 	('10/22/10','10','6','0'),
# 	('10/23/10','10','7','0'),
# 	('10/24/10','10','1','0'),
# 	('10/25/10','10','2','0'),
# 	('10/26/10','10','3','0'),
# 	('10/27/10','10','4','0'),
# 	('10/28/10','10','5','0'),
# 	('10/29/10','10','6','0'),
# 	('10/30/10','10','7','0'),
# 	('10/31/10','10','1','0'),
# 	('11/1/10','11','2','0'),
# 	('11/2/10','11','3','0'),
# 	('11/3/10','11','4','0'),
# 	('11/4/10','11','5','0'),
# 	('11/5/10','11','6','0'),
# 	('11/6/10','11','7','0'),
# 	('11/7/10','11','1','0'),
# 	('11/8/10','11','2','0'),
# 	('11/9/10','11','3','0'),
# 	('11/10/10','11','4','0'),
# 	('11/11/10','11','5','0'),
# 	('11/12/10','11','6','0'),
# 	('11/13/10','11','7','0'),
# 	('11/14/10','11','1','0'),
# 	('11/15/10','11','2','0'),
# 	('11/16/10','11','3','0'),
# 	('11/17/10','11','4','0'),
# 	('11/18/10','11','5','0'),
# 	('11/19/10','11','6','0'),
# 	('11/20/10','11','7','0'),
# 	('11/21/10','11','1','0'),
# 	('11/22/10','11','2','1'),
# 	('11/23/10','11','3','1'),
# 	('11/24/10','11','4','1'),
# 	('11/25/10','11','5','1'),
# 	('11/26/10','11','6','1'),
# 	('11/27/10','11','7','1'),
# 	('11/28/10','11','1','1'),
# 	('11/29/10','11','2','1'),
# 	('11/30/10','11','3','0'),
# 	('12/1/10','12','4','0'),
# 	('12/2/10','12','5','0'),
# 	('12/3/10','12','6','0'),
# 	('12/4/10','12','7','0'),
# 	('12/5/10','12','1','0'),
# 	('12/6/10','12','2','0'),
# 	('12/7/10','12','3','0'),
# 	('12/8/10','12','4','0'),
# 	('12/9/10','12','5','0'),
# 	('12/10/10','12','6','0'),
# 	('12/11/10','12','7','0'),
# 	('12/12/10','12','1','0'),
# 	('12/13/10','12','2','0'),
# 	('12/14/10','12','3','0'),
# 	('12/15/10','12','4','0'),
# 	('12/16/10','12','5','0'),
# 	('12/17/10','12','6','0'),
# 	('12/18/10','12','7','0'),
# 	('12/19/10','12','1','0'),
# 	('12/20/10','12','2','0'),
# 	('12/21/10','12','3','0'),
# 	('12/22/10','12','4','1'),
# 	('12/23/10','12','5','1'),
# 	('12/24/10','12','6','1'),
# 	('12/25/10','12','7','1'),
# 	('12/26/10','12','1','1'),
# 	('12/27/10','12','2','1'),
# 	('12/28/10','12','3','1'),
# 	('12/29/10','12','4','1'),
# 	('12/30/10','12','5','1'),
# 	('12/31/10','12','6','1'),
# 	('1/1/11','1','7','1'),
# 	('1/2/11','1','1','1'),
# 	('1/3/11','1','2','1'),
# 	('1/4/11','1','3','0'),
# 	('1/5/11','1','4','0'),
# 	('1/6/11','1','5','0'),
# 	('1/7/11','1','6','0'),
# 	('1/8/11','1','7','0'),
# 	('1/9/11','1','1','0'),
# 	('1/10/11','1','2','0'),
# 	('1/11/11','1','3','0'),
# 	('1/12/11','1','4','0'),
# 	('1/13/11','1','5','0'),
# 	('1/14/11','1','6','0'),
# 	('1/15/11','1','7','0'),
# 	('1/16/11','1','1','0'),
# 	('1/17/11','1','2','0'),
# 	('1/18/11','1','3','0'),
# 	('1/19/11','1','4','0'),
# 	('1/20/11','1','5','0'),
# 	('1/21/11','1','6','0'),
# 	('1/22/11','1','7','0'),
# 	('1/23/11','1','1','0'),
# 	('1/24/11','1','2','0'),
# 	('1/25/11','1','3','0'),
# 	('1/26/11','1','4','0'),
# 	('1/27/11','1','5','0'),
# 	('1/28/11','1','6','0'),
# 	('1/29/11','1','7','0'),
# 	('1/30/11','1','1','0'),
# 	('1/31/11','1','2','0'),
# 	('2/1/11','2','3','0'),
# 	('2/2/11','2','4','0'),
# 	('2/3/11','2','5','0'),
# 	('2/4/11','2','6','0'),
# 	('2/5/11','2','7','0'),
# 	('2/6/11','2','1','0'),
# 	('2/7/11','2','2','0'),
# 	('2/8/11','2','3','0'),
# 	('2/9/11','2','4','0'),
# 	('2/10/11','2','5','0'),
# 	('2/11/11','2','6','0'),
# 	('2/12/11','2','7','0'),
# 	('2/13/11','2','1','0'),
# 	('2/14/11','2','2','0'),
# 	('2/15/11','2','3','0'),
# 	('2/16/11','2','4','0'),
# 	('2/17/11','2','5','0'),
# 	('2/18/11','2','6','0'),
# 	('2/19/11','2','7','0'),
# 	('2/20/11','2','1','0'),
# 	('2/21/11','2','2','0'),
# 	('2/22/11','2','3','0'),
# 	('2/23/11','2','4','0'),
# 	('2/24/11','2','5','0'),
# 	('2/25/11','2','6','0'),
# 	('2/26/11','2','7','0'),
# 	('2/27/11','2','1','0'),
# 	('2/28/11','2','2','0'),
# 	('3/1/11','3','3','0'),
# 	('3/2/11','3','4','0'),
# 	('3/3/11','3','5','0'),
# 	('3/4/11','3','6','0'),
# 	('3/5/11','3','7','0'),
# 	('3/6/11','3','1','0'),
# 	('3/7/11','3','2','0'),
# 	('3/8/11','3','3','0'),
# 	('3/9/11','3','4','0'),
# 	('3/10/11','3','5','0'),
# 	('3/11/11','3','6','0'),
# 	('3/12/11','3','7','0'),
# 	('3/13/11','3','1','0'),
# 	('3/14/11','3','2','0'),
# 	('3/15/11','3','3','0'),
# 	('3/16/11','3','4','0'),
# 	('3/17/11','3','5','0'),
# 	('3/18/11','3','6','0'),
# 	('3/19/11','3','7','0'),
# 	('3/20/11','3','1','0'),
# 	('3/21/11','3','2','0'),
# 	('3/22/11','3','3','0'),
# 	('3/23/11','3','4','0'),
# 	('3/24/11','3','5','0'),
# 	('3/25/11','3','6','0'),
# 	('3/26/11','3','7','0'),
# 	('3/27/11','3','1','0'),
# 	('3/28/11','3','2','0'),
# 	('3/29/11','3','3','0'),
# 	('3/30/11','3','4','0'),
# 	('3/31/11','3','5','0'),
# 	('4/1/11','4','6','0'),
# 	('4/2/11','4','7','0'),
# 	('4/3/11','4','1','0'),
# 	('4/4/11','4','2','0'),
# 	('4/5/11','4','3','0'),
# 	('4/6/11','4','4','0'),
# 	('4/7/11','4','5','0'),
# 	('4/8/11','4','6','0'),
# 	('4/9/11','4','7','0'),
# 	('4/10/11','4','1','0'),
# 	('4/11/11','4','2','0'),
# 	('4/12/11','4','3','0'),
# 	('4/13/11','4','4','0'),
# 	('4/14/11','4','5','0'),
# 	('4/15/11','4','6','0'),
# 	('4/16/11','4','7','0'),
# 	('4/17/11','4','1','0'),
# 	('4/18/11','4','2','0'),
# 	('4/19/11','4','3','0'),
# 	('4/20/11','4','4','0'),
# 	('4/21/11','4','5','0'),
# 	('4/22/11','4','6','0'),
# 	('4/23/11','4','7','0'),
# 	('4/24/11','4','1','0'),
# 	('4/25/11','4','2','0'),
# 	('4/26/11','4','3','0'),
# 	('4/27/11','4','4','0'),
# 	('4/28/11','4','5','0'),
# 	('4/29/11','4','6','0'),
# 	('4/30/11','4','7','0'),
# 	('5/1/11','5','1','0'),
# 	('5/2/11','5','2','0'),
# 	('5/3/11','5','3','0'),
# 	('5/4/11','5','4','0'),
# 	('5/5/11','5','5','0'),
# 	('5/6/11','5','6','0'),
# 	('5/7/11','5','7','0'),
# 	('5/8/11','5','1','0'),
# 	('5/9/11','5','2','0'),
# 	('5/10/11','5','3','0'),
# 	('5/11/11','5','4','0'),
# 	('5/12/11','5','5','0'),
# 	('5/13/11','5','6','0'),
# 	('5/14/11','5','7','0'),
# 	('5/15/11','5','1','0'),
# 	('5/16/11','5','2','0'),
# 	('5/17/11','5','3','0'),
# 	('5/18/11','5','4','0'),
# 	('5/19/11','5','5','0'),
# 	('5/20/11','5','6','0'),
# 	('5/21/11','5','7','0'),
# 	('5/22/11','5','1','0'),
# 	('5/23/11','5','2','0'),
# 	('5/24/11','5','3','0'),
# 	('5/25/11','5','4','0'),
# 	('5/26/11','5','5','0'),
# 	('5/27/11','5','6','0'),
# 	('5/28/11','5','7','0'),
# 	('5/29/11','5','1','0'),
# 	('5/30/11','5','2','0'),
# 	('5/31/11','5','3','0'),
# 	('6/1/11','6','4','0'),
# 	('6/2/11','6','5','0'),
# 	('6/3/11','6','6','0'),
# 	('6/4/11','6','7','0'),
# 	('6/5/11','6','1','0'),
# 	('6/6/11','6','2','0'),
# 	('6/7/11','6','3','0'),
# 	('6/8/11','6','4','0'),
# 	('6/9/11','6','5','0'),
# 	('6/10/11','6','6','0'),
# 	('6/11/11','6','7','0'),
# 	('6/12/11','6','1','0'),
# 	('6/13/11','6','2','0'),
# 	('6/14/11','6','3','0'),
# 	('6/15/11','6','4','0'),
# 	('6/16/11','6','5','0'),
# 	('6/17/11','6','6','0'),
# 	('6/18/11','6','7','0'),
# 	('6/19/11','6','1','0'),
# 	('6/20/11','6','2','0'),
# 	('6/21/11','6','3','0'),
# 	('6/22/11','6','4','0'),
# 	('6/23/11','6','5','0'),
# 	('6/24/11','6','6','0'),
# 	('6/25/11','6','7','0'),
# 	('6/26/11','6','1','0'),
# 	('6/27/11','6','2','0'),
# 	('6/28/11','6','3','0'),
# 	('6/29/11','6','4','0'),
# 	('6/30/11','6','5','0'),
# 	('7/1/11','7','6','0'),
# 	('7/2/11','7','7','1'),
# 	('7/3/11','7','1','1'),
# 	('7/4/11','7','2','1'),
# 	('7/5/11','7','3','1'),
# 	('7/6/11','7','4','1'),
# 	('7/7/11','7','5','1'),
# 	('7/8/11','7','6','1'),
# 	('7/9/11','7','7','1'),
# 	('7/10/11','7','1','0'),
# 	('7/11/11','7','2','0'),
# 	('7/12/11','7','3','0'),
# 	('7/13/11','7','4','0'),
# 	('7/14/11','7','5','0'),
# 	('7/15/11','7','6','0'),
# 	('7/16/11','7','7','0'),
# 	('7/17/11','7','1','0'),
# 	('7/18/11','7','2','0'),
# 	('7/19/11','7','3','0'),
# 	('7/20/11','7','4','0'),
# 	('7/21/11','7','5','0'),
# 	('7/22/11','7','6','0'),
# 	('7/23/11','7','7','0'),
# 	('7/24/11','7','1','0'),
# 	('7/25/11','7','2','0'),
# 	('7/26/11','7','3','0'),
# 	('7/27/11','7','4','0'),
# 	('7/28/11','7','5','0'),
# 	('7/29/11','7','6','0'),
# 	('7/30/11','7','7','0'),
# 	('7/31/11','7','1','0'),
# 	('8/1/11','8','2','0'),
# 	('8/2/11','8','3','0'),
# 	('8/3/11','8','4','0'),
# 	('8/4/11','8','5','0'),
# 	('8/5/11','8','6','0'),
# 	('8/6/11','8','7','0'),
# 	('8/7/11','8','1','0'),
# 	('8/8/11','8','2','0'),
# 	('8/9/11','8','3','0'),
# 	('8/10/11','8','4','0'),
# 	('8/11/11','8','5','0'),
# 	('8/12/11','8','6','0'),
# 	('8/13/11','8','7','0'),
# 	('8/14/11','8','1','0'),
# 	('8/15/11','8','2','0'),
# 	('8/16/11','8','3','0'),
# 	('8/17/11','8','4','0'),
# 	('8/18/11','8','5','0'),
# 	('8/19/11','8','6','0'),
# 	('8/20/11','8','7','0'),
# 	('8/21/11','8','1','0'),
# 	('8/22/11','8','2','0'),
# 	('8/23/11','8','3','0'),
# 	('8/24/11','8','4','0'),
# 	('8/25/11','8','5','0'),
# 	('8/26/11','8','6','0'),
# 	('8/27/11','8','7','0'),
# 	('8/28/11','8','1','0'),
# 	('8/29/11','8','2','0'),
# 	('8/30/11','8','3','0'),
# 	('8/31/11','8','4','0'),
# 	('9/1/11','9','5','0'),
# 	('9/2/11','9','6','0'),
# 	('9/3/11','9','7','0'),
# 	('9/4/11','9','1','0'),
# 	('9/5/11','9','2','0'),
# 	('9/6/11','9','3','0'),
# 	('9/7/11','9','4','0'),
# 	('9/8/11','9','5','0'),
# 	('9/9/11','9','6','0'),
# 	('9/10/11','9','7','0'),
# 	('9/11/11','9','1','0'),
# 	('9/12/11','9','2','0'),
# 	('9/13/11','9','3','0'),
# 	('9/14/11','9','4','0'),
# 	('9/15/11','9','5','0'),
# 	('9/16/11','9','6','0'),
# 	('9/17/11','9','7','0'),
# 	('9/18/11','9','1','0'),
# 	('9/19/11','9','2','0'),
# 	('9/20/11','9','3','0'),
# 	('9/21/11','9','4','0'),
# 	('9/22/11','9','5','0'),
# 	('9/23/11','9','6','0'),
# 	('9/24/11','9','7','0'),
# 	('9/25/11','9','1','0'),
# 	('9/26/11','9','2','0'),
# 	('9/27/11','9','3','0'),
# 	('9/28/11','9','4','0'),
# 	('9/29/11','9','5','0'),
# 	('9/30/11','9','6','0'),
# 	('10/1/11','10','7','0'),
# 	('10/2/11','10','1','0'),
# 	('10/3/11','10','2','0'),
# 	('10/4/11','10','3','0'),
# 	('10/5/11','10','4','0'),
# 	('10/6/11','10','5','0'),
# 	('10/7/11','10','6','0'),
# 	('10/8/11','10','7','0'),
# 	('10/9/11','10','1','0'),
# 	('10/10/11','10','2','0'),
# 	('10/11/11','10','3','0'),
# 	('10/12/11','10','4','0'),
# 	('10/13/11','10','5','0'),
# 	('10/14/11','10','6','0'),
# 	('10/15/11','10','7','0'),
# 	('10/16/11','10','1','0'),
# 	('10/17/11','10','2','0'),
# 	('10/18/11','10','3','0'),
# 	('10/19/11','10','4','0'),
# 	('10/20/11','10','5','0'),
# 	('10/21/11','10','6','0'),
# 	('10/22/11','10','7','0'),
# 	('10/23/11','10','1','0'),
# 	('10/24/11','10','2','0'),
# 	('10/25/11','10','3','0'),
# 	('10/26/11','10','4','0'),
# 	('10/27/11','10','5','0'),
# 	('10/28/11','10','6','0'),
# 	('10/29/11','10','7','0'),
# 	('10/30/11','10','1','0'),
# 	('10/31/11','10','2','0'),
# 	('11/1/11','11','3','0'),
# 	('11/2/11','11','4','0'),
# 	('11/3/11','11','5','0'),
# 	('11/4/11','11','6','0'),
# 	('11/5/11','11','7','0'),
# 	('11/6/11','11','1','0'),
# 	('11/7/11','11','2','0'),
# 	('11/8/11','11','3','0'),
# 	('11/9/11','11','4','0'),
# 	('11/10/11','11','5','0'),
# 	('11/11/11','11','6','0'),
# 	('11/12/11','11','7','0'),
# 	('11/13/11','11','1','0'),
# 	('11/14/11','11','2','0'),
# 	('11/15/11','11','3','0'),
# 	('11/16/11','11','4','0'),
# 	('11/17/11','11','5','0'),
# 	('11/18/11','11','6','0'),
# 	('11/19/11','11','7','0'),
# 	('11/20/11','11','1','0'),
# 	('11/21/11','11','2','0'),
# 	('11/22/11','11','3','0'),
# 	('11/23/11','11','4','0'),
# 	('11/24/11','11','5','1'),
# 	('11/25/11','11','6','1'),
# 	('11/26/11','11','7','1'),
# 	('11/27/11','11','1','1'),
# 	('11/28/11','11','2','1'),
# 	('11/29/11','11','3','1'),
# 	('11/30/11','11','4','0'),
# 	('12/1/11','12','5','0'),
# 	('12/2/11','12','6','0'),
# 	('12/3/11','12','7','0'),
# 	('12/4/11','12','1','0'),
# 	('12/5/11','12','2','0'),
# 	('12/6/11','12','3','0'),
# 	('12/7/11','12','4','0'),
# 	('12/8/11','12','5','0'),
# 	('12/9/11','12','6','0'),
# 	('12/10/11','12','7','0'),
# 	('12/11/11','12','1','0'),
# 	('12/12/11','12','2','0'),
# 	('12/13/11','12','3','0'),
# 	('12/14/11','12','4','0'),
# 	('12/15/11','12','5','0'),
# 	('12/16/11','12','6','0'),
# 	('12/17/11','12','7','0'),
# 	('12/18/11','12','1','0'),
# 	('12/19/11','12','2','0'),
# 	('12/20/11','12','3','0'),
# 	('12/21/11','12','4','0'),
# 	('12/22/11','12','5','0'),
# 	('12/23/11','12','6','0'),
# 	('12/24/11','12','7','1'),
# 	('12/25/11','12','1','1'),
# 	('12/26/11','12','2','1'),
# 	('12/27/11','12','3','1'),
# 	('12/28/11','12','4','1'),
# 	('12/29/11','12','5','1'),
# 	('12/30/11','12','6','1'),
# 	('12/31/11','12','7','1'),
# 	('1/1/12','1','1','1'),
# 	('1/2/12','1','2','1'),
# 	('1/3/12','1','3','0'),
# 	('1/4/12','1','4','0'),
# 	('1/5/12','1','5','0'),
# 	('1/6/12','1','6','0'),
# 	('1/7/12','1','7','0'),
# 	('1/8/12','1','1','0'),
# 	('1/9/12','1','2','0'),
# 	('1/10/12','1','3','0'),
# 	('1/11/12','1','4','0'),
# 	('1/12/12','1','5','0'),
# 	('1/13/12','1','6','0'),
# 	('1/14/12','1','7','0'),
# 	('1/15/12','1','1','0'),
# 	('1/16/12','1','2','0'),
# 	('1/17/12','1','3','0'),
# 	('1/18/12','1','4','0'),
# 	('1/19/12','1','5','0'),
# 	('1/20/12','1','6','0'),
# 	('1/21/12','1','7','0'),
# 	('1/22/12','1','1','0'),
# 	('1/23/12','1','2','0'),
# 	('1/24/12','1','3','0'),
# 	('1/25/12','1','4','0'),
# 	('1/26/12','1','5','0'),
# 	('1/27/12','1','6','0'),
# 	('1/28/12','1','7','0'),
# 	('1/29/12','1','1','0'),
# 	('1/30/12','1','2','0'),
# 	('1/31/12','1','3','0'),
# 	('2/1/12','2','4','0'),
# 	('2/2/12','2','5','0'),
# 	('2/3/12','2','6','0'),
# 	('2/4/12','2','7','0'),
# 	('2/5/12','2','1','0'),
# 	('2/6/12','2','2','0'),
# 	('2/7/12','2','3','0'),
# 	('2/8/12','2','4','0'),
# 	('2/9/12','2','5','0'),
# 	('2/10/12','2','6','0'),
# 	('2/11/12','2','7','0'),
# 	('2/12/12','2','1','0'),
# 	('2/13/12','2','2','0'),
# 	('2/14/12','2','3','0'),
# 	('2/15/12','2','4','0'),
# 	('2/16/12','2','5','0'),
# 	('2/17/12','2','6','0'),
# 	('2/18/12','2','7','0'),
# 	('2/19/12','2','1','0'),
# 	('2/20/12','2','2','0'),
# 	('2/21/12','2','3','0'),
# 	('2/22/12','2','4','0'),
# 	('2/23/12','2','5','0'),
# 	('2/24/12','2','6','0'),
# 	('2/25/12','2','7','0'),
# 	('2/26/12','2','1','0'),
# 	('2/27/12','2','2','0'),
# 	('2/28/12','2','3','0'),
# 	('2/29/12','2','4','0'),
# 	('3/1/12','3','5','0'),
# 	('3/2/12','3','6','0'),
# 	('3/3/12','3','7','0'),
# 	('3/4/12','3','1','0'),
# 	('3/5/12','3','2','0'),
# 	('3/6/12','3','3','0'),
# 	('3/7/12','3','4','0'),
# 	('3/8/12','3','5','0'),
# 	('3/9/12','3','6','0'),
# 	('3/10/12','3','7','0'),
# 	('3/11/12','3','1','0'),
# 	('3/12/12','3','2','0'),
# 	('3/13/12','3','3','0'),
# 	('3/14/12','3','4','0'),
# 	('3/15/12','3','5','0'),
# 	('3/16/12','3','6','0'),
# 	('3/17/12','3','7','0');
# Out:
#  * postgresql://gpadmin:***@gpdb-sandbox:5432/gpadmin
# Done.
# Done.
# 807 rows affected.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS pricing.routes CASCADE;
#
# CREATE TABLE pricing.routes (
#     ID SERIAL,
#     Route_Type INTEGER,
#     Origin VARCHAR(3),
#     Destination VARCHAR(3),
#     Hub VARCHAR(3)
#     ) DISTRIBUTED BY (Origin, Destination);
#
# -- all large and medium airport pairs have 1 connection flights
#
# INSERT INTO pricing.routes
#     (Route_Type, Origin, Destination, Hub)
# SELECT
#     1,
#     t1.FAA,
#     t2.FAA,
#     CASE WHEN RANDOM()<0.5 THEN t1.hub_assignment ELSE t2.hub_assignment END
# FROM
#     pricing.airports t1
#     JOIN pricing.airports t2
#         ON (t1.FAA <> t2.FAA)
# WHERE
#     t1.Airport_Role IN ('P-L','P-M')
#     AND t2.Airport_Role IN ('P-L','P-M')
#     AND (t1.Is_Hub=0
#          AND t2.Is_Hub=0);
#
# -- from all large sized airports to AA Hubs we have nonstop flights
#
# INSERT INTO
#     pricing.routes (Route_Type, Origin, Destination, Hub)
# SELECT
#     2,
#     t1.FAA,
#     t2.FAA,
#     NULL
# FROM
#     pricing.airports t1
#     JOIN pricing.airports t2
#         ON (t1.FAA <> t2.FAA)
# WHERE
#     t1.Airport_Role='P-L'
#     AND t2.Is_Hub=1;
#
# -- from all AA Hubs we have nonstop flights to large airports
#
# INSERT INTO
#     pricing.routes (Route_Type, Origin, Destination, Hub)
# SELECT
#     3,
#     t1.FAA,
#     t2.FAA,
#     NULL
# FROM
#     pricing.airports t1
#     JOIN pricing.airports t2
#         ON (t1.FAA <> t2.FAA)
# WHERE
#     t1.Is_Hub=1
#     AND t2.Airport_Role='P-L';
#
# -- from all medium sized airports to AA Hubs we have nonstop flights
#
# INSERT INTO pricing.routes (Route_Type, Origin, Destination, Hub)
# SELECT 4, t1.FAA, t2.FAA, NULL
# FROM
# pricing.airports t1 JOIN pricing.airports t2 ON (t1.FAA <> t2.FAA)
# WHERE
# t1.Airport_Role='P-M' AND t2.Is_Hub=1;
#
#
# -- from all AA Hubs we have nonstop flights to medium airports
#
# INSERT INTO pricing.routes (Route_Type, Origin, Destination, Hub)
# SELECT 5, t1.FAA, t2.FAA, NULL
# FROM
# pricing.airports t1 JOIN pricing.airports t2 ON (t1.FAA <> t2.FAA)
# WHERE
# t1.Is_Hub=1 AND t2.Airport_Role='P-M';
